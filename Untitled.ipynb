# %%
import numpy as np
import matplotlib.pyplot as plt

bisection = plt.imread('flowchart_bisection.png')
fixed_point = plt.imread('flowchart_fixed_point.png')
secant = plt.imread('metode_secant.jpg')
nevile = plt.imread('neville_algorithm.jpeg')

# %% [markdown]
# ## **EVALUASI PRAKTIKUM METODE NUMERIK**

# %% [markdown]
# ### Buatlah program dan pengerjaan manual metode numerik berikut.

# %% [markdown]
# #### **1. Metode Tertutup : score(10)**
# * Metode Biseksi

# %%
plt.figure(figsize=(10,10))
plt.imshow(bisection)
plt.title("BISECTION FLOWCHART", fontsize=20, pad=10, c='g')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **2. Metode Terbuka : score(40)**
# * Metode Iterasi Titik Tetap
# * Metode Secant

# %%
plt.figure(figsize=(10,10))
plt.imshow(fixed_point)
plt.title("FIXED_POINT FLOWCHART", fontsize=20, pad=10, c='g')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(secant)
plt.title("SECANT FLOWCHART", fontsize=20, pad=10, c='g')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **3. Interpolasi : score(50)**
# *  Interpolasi Navile's

# %%
plt.figure(figsize=(10,10))
plt.imshow(nevile)
plt.title("NEVILLE'S ALGORITM", fontsize=20, pad=10, c='g')
plt.tight_layout()
plt.show()
